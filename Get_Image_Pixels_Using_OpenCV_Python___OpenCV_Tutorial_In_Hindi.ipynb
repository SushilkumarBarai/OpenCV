# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-55ca9872-cd46-4202-b089-7bd776266168" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55ca9872-cd46-4202-b089-7bd776266168">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving srk.jpg to srk (1).jpg

# %%
# Import Library
 


 
# Read & Show Image
img_path = r"srk.jpg"
 
img = cv2.imread(img_path)
img = cv2.resize(img,(int(img.shape[1]*0.5), int(img.shape[0]*0.5)))
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=149x84 at 0x7FCAF5114510>

# %%
img
# Out:
# array([[[246, 227, 219],
#         [247, 228, 220],
#         [248, 229, 221],
#         ...,
#         [244, 223, 221],
#         [244, 223, 221],
#         [244, 223, 221]],
#
#        [[246, 227, 219],
#         [247, 228, 220],
#         [248, 229, 221],
#         ...,
#         [244, 224, 219],
#         [244, 224, 219],
#         [243, 223, 218]],
#
#        [[246, 227, 219],
#         [247, 228, 220],
#         [248, 229, 221],
#         ...,
#         [244, 224, 219],
#         [243, 223, 218],
#         [242, 222, 217]],
#
#        ...,
#
#        [[228, 213, 197],
#         [227, 212, 196],
#         [226, 210, 197],
#         ...,
#         [200, 185, 166],
#         [205, 189, 169],
#         [155, 138, 117]],
#
#        [[228, 213, 197],
#         [227, 212, 196],
#         [226, 210, 197],
#         ...,
#         [174, 160, 141],
#         [181, 165, 146],
#         [147, 130, 111]],
#
#        [[228, 213, 197],
#         [227, 212, 196],
#         [226, 210, 197],
#         ...,
#         [206, 191, 172],
#         [205, 189, 171],
#         [200, 182, 165]]], dtype=uint8)

# %%
img.shape
# Out:
# (84, 149, 3)

# %%
img.size
# Out:
# 37548

# %%
#Access Single Pixel of Image

# %%
img[20,100]
# Out:
# array([243, 225, 214], dtype=uint8)

# %%
#Show single pixel of Image as Image

# %%
#Show image Row wise
for i in range(img.shape[0]):
    cv2_imshow( img[0:i+1, :])
 
    if cv2.waitKey(27) & 0xff == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=149x1 at 0x7FCAF5114890>
# <PIL.Image.Image image mode=RGB size=149x2 at 0x7FCAF5114890>
# <PIL.Image.Image image mode=RGB size=149x3 at 0x7FCAF5114810>
# <PIL.Image.Image image mode=RGB size=149x4 at 0x7FCAF5114C90>
# <PIL.Image.Image image mode=RGB size=149x5 at 0x7FCAF5114E50>
# <PIL.Image.Image image mode=RGB size=149x6 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x7 at 0x7FCB05063810>
# <PIL.Image.Image image mode=RGB size=149x8 at 0x7FCAF51141D0>
# <PIL.Image.Image image mode=RGB size=149x9 at 0x7FCB05063810>
# <PIL.Image.Image image mode=RGB size=149x10 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x11 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x12 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x13 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x14 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x15 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x16 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x17 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x18 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x19 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x20 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x21 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x22 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x23 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x24 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x25 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x26 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x27 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x28 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x29 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x30 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x31 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x32 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x33 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x34 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x35 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x36 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x37 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x38 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x39 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x40 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x41 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x42 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x43 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x44 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x45 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x46 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x47 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x48 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x49 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x50 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x51 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x52 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x53 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x54 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x55 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x56 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x57 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x58 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x59 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x60 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x61 at 0x7FCAF5297050>
# <PIL.Image.Image image mode=RGB size=149x62 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x63 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x64 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x65 at 0x7FCAF5297090>
# <PIL.Image.Image image mode=RGB size=149x66 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x67 at 0x7FCAF5114E50>
# <PIL.Image.Image image mode=RGB size=149x68 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x69 at 0x7FCB05063810>
# <PIL.Image.Image image mode=RGB size=149x70 at 0x7FCAF5114E50>
# <PIL.Image.Image image mode=RGB size=149x71 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x72 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x73 at 0x7FCAF5114E50>
# <PIL.Image.Image image mode=RGB size=149x74 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x75 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x76 at 0x7FCAF5114E50>
# <PIL.Image.Image image mode=RGB size=149x77 at 0x7FCB05063810>
# <PIL.Image.Image image mode=RGB size=149x78 at 0x7FCB05796E50>
# <PIL.Image.Image image mode=RGB size=149x79 at 0x7FCAF5114E50>
# <PIL.Image.Image image mode=RGB size=149x80 at 0x7FCAF5303AD0>
# <PIL.Image.Image image mode=RGB size=149x81 at 0x7FCB05063810>
# <PIL.Image.Image image mode=RGB size=149x82 at 0x7FCAF5114E50>
# <PIL.Image.Image image mode=RGB size=149x83 at 0x7FCB056C6950>
# <PIL.Image.Image image mode=RGB size=149x84 at 0x7FCAF5303AD0>

# %%
#Show image Column wise

for i in range(img.shape[1]):
    cv2_imshow( img[:, 0:i+1])
 
    if cv2.waitKey(27) & 0xff == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=2x84 at 0x7FCAF5112210>
# <PIL.Image.Image image mode=RGB size=3x84 at 0x7FCAF5136110>
# <PIL.Image.Image image mode=RGB size=4x84 at 0x7FCAF5136990>
# <PIL.Image.Image image mode=RGB size=5x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=6x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=7x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=8x84 at 0x7FCAF5136990>
# <PIL.Image.Image image mode=RGB size=9x84 at 0x7FCAF5131510>
# <PIL.Image.Image image mode=RGB size=10x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=11x84 at 0x7FCAF5136110>
# <PIL.Image.Image image mode=RGB size=12x84 at 0x7FCAF5131910>
# <PIL.Image.Image image mode=RGB size=13x84 at 0x7FCAF5131910>
# <PIL.Image.Image image mode=RGB size=14x84 at 0x7FCAF5131910>
# <PIL.Image.Image image mode=RGB size=15x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=16x84 at 0x7FCAF5117110>
# <PIL.Image.Image image mode=RGB size=17x84 at 0x7FCAF5131850>
# <PIL.Image.Image image mode=RGB size=18x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=19x84 at 0x7FCB057964D0>
# <PIL.Image.Image image mode=RGB size=20x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=21x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=22x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=23x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=24x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=25x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=26x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=27x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=28x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=29x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=30x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=31x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=32x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=33x84 at 0x7FCAF5131510>
# <PIL.Image.Image image mode=RGB size=34x84 at 0x7FCAF5131410>
# <PIL.Image.Image image mode=RGB size=35x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=36x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=37x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=38x84 at 0x7FCAF5131850>
# <PIL.Image.Image image mode=RGB size=39x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=40x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=41x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=42x84 at 0x7FCAF5131850>
# <PIL.Image.Image image mode=RGB size=43x84 at 0x7FCAF5112210>
# <PIL.Image.Image image mode=RGB size=44x84 at 0x7FCB057964D0>
# <PIL.Image.Image image mode=RGB size=45x84 at 0x7FCAF5131850>
# <PIL.Image.Image image mode=RGB size=46x84 at 0x7FCAF5112210>
# <PIL.Image.Image image mode=RGB size=47x84 at 0x7FCAF5117110>
# <PIL.Image.Image image mode=RGB size=48x84 at 0x7FCAF5131490>
# <PIL.Image.Image image mode=RGB size=49x84 at 0x7FCAF5131410>
# <PIL.Image.Image image mode=RGB size=50x84 at 0x7FCAF5117110>
# <PIL.Image.Image image mode=RGB size=51x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=52x84 at 0x7FCB057964D0>
# <PIL.Image.Image image mode=RGB size=53x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=54x84 at 0x7FCAF5112F10>
# <PIL.Image.Image image mode=RGB size=55x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=56x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=57x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=58x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=59x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=60x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=61x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=62x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=63x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=64x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=65x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=66x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=67x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=68x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=69x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=70x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=71x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=72x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=73x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=74x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=75x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=76x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=77x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=78x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=79x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=80x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=81x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=82x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=83x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=84x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=85x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=86x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=87x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=88x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=89x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=90x84 at 0x7FCAF5131490>
# <PIL.Image.Image image mode=RGB size=91x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=92x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=93x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=94x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=95x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=96x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=97x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=98x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=99x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=100x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=101x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=102x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=103x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=104x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=105x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=106x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=107x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=108x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=109x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=110x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=111x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=112x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=113x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=114x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=115x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=116x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=117x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=118x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=119x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=120x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=121x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=122x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=123x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=124x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=125x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=126x84 at 0x7FCAF5136990>
# <PIL.Image.Image image mode=RGB size=127x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=128x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=129x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=130x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=131x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=132x84 at 0x7FCAF5136990>
# <PIL.Image.Image image mode=RGB size=133x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=134x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=135x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=136x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=137x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=138x84 at 0x7FCAF5136990>
# <PIL.Image.Image image mode=RGB size=139x84 at 0x7FCAF5136490>
# <PIL.Image.Image image mode=RGB size=140x84 at 0x7FCAF5136090>
# <PIL.Image.Image image mode=RGB size=141x84 at 0x7FCAF5136050>
# <PIL.Image.Image image mode=RGB size=142x84 at 0x7FCAF5136950>
# <PIL.Image.Image image mode=RGB size=143x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=144x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=145x84 at 0x7FCAF5131C50>
# <PIL.Image.Image image mode=RGB size=146x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=147x84 at 0x7FCAF5117110>
# <PIL.Image.Image image mode=RGB size=148x84 at 0x7FCAF5136410>
# <PIL.Image.Image image mode=RGB size=149x84 at 0x7FCAF5136990>
